# %%
import pandas as pd

df_sc = pd.read_csv("data/raw/SC/ar6.csv", sep=",")

# %% [markdown]
# # EDA - Exploratory Data Analysis
#
# Nesse notebook iremos explorar nossos dados para entender a disposição e o comportamento de nossos dados. Essa etapa é posterior ao estudo do nosso dataset para compreender suas colunas e os dados que temos disponíveis.
#
# Na célula abaixo, vamos identificar se os tipos de variável são os corretos para trabalhar com o nosso dataframe.

# %%
df_sc.info(memory_usage="deep")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 133264 entries, 0 to 133263
# Data columns (total 66 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Setor de emissão        133264 non-null  str
#  1   Categoria emissora      133264 non-null  str
#  2   Sub-categoria emissora  133264 non-null  str
#  3   Produto ou sistema      133264 non-null  str
#  4   Detalhamento            133264 non-null  str
#  5   Recorte                 124162 non-null  str
#  6   Atividade geral         133264 non-null  str
#  7   Bioma                   133244 non-null  str
#  8   Emissão/Remoção/Bunker  133264 non-null  str
#  9   Gás                     133264 non-null  str
#  10  Cidade                  133264 non-null  str
#  11  1970                    133264 non-null  float64
#  12  1971                    133264 non-null  float64
#  13  1972                    133264 non-null  float64
# ...

# %% [markdown]
# As variáveis podem ser utilizadas dessa forma, mas para reduzir o uso excessivo de memória podemos alterar as variáveis do tipo _string_ para o tipo _category_. Esse tratamento irá acelerar consideravelmente a velocidade de processamento dos nossos dados durante as análises.

# %% [markdown]
# Na célula abaixo definimos as colunas que serão de interesse para a análise:

# %%
df_sc = df_sc[['Setor de emissão',
               'Categoria emissora',
               'Sub-categoria emissora',
               'Produto ou sistema',
               'Detalhamento',
               'Atividade geral',
               'Cidade',
               '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
               '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
               '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
               '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
               '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
               '2020', '2021', '2022', '2023', '2024']]

# %% [markdown]
# Reconhecendo quais são os Setores de Emissão listados:

# %%
df_sc.groupby(by=['Setor de emissão']).count()
# Out:
#                                     Categoria emissora  \
# Setor de emissão
# Agropecuária                                     56658
# Energia                                          19170
# Mudança de Uso da Terra e Floresta               48064
# Processos Industriais                              594
# Resíduos                                          8778
#
#                                     Sub-categoria emissora  \
# Setor de emissão
# Agropecuária                                         56658
# Energia                                              19170
# Mudança de Uso da Terra e Floresta                   48064
# Processos Industriais                                  594
# Resíduos                                              8778
#
#                                     Produto ou sistema  Detalhamento  \
# Setor de emissão
# Agropecuária                                     56658         56658
# Energia                                          19170         19170
# ...

# %% [markdown]
# #### Wide -> Long
#
# Nosso dataset segue o formato _wide_ para alocação dos dados de emissão de cada ano. Para facilitar nossas análises, iremos transformar para o formato _long_, assim criando as colunas "Ano" e "CO2e (t)" para fazer a alocação dos valores.
#
# Esse tratamento foi implementado no arquivo "02_Data_Preparation".
